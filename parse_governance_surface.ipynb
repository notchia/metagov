# %%
import os
import requests
import pprint
import pandas as pd
from solidity_parser import parser

# %%
if not os.path.isdir('/tmp'):
    os.mkdir('/tmp')

# %% [markdown]
# # Construct governance surface of a Solidity smart contract
# - [x] Parse structure of the smart contract
# - [ ] Get comments corresponding to function/parameter definitions to contextualize the structure
# - [ ] Select subset of functions/parameters relevant to governance, preserving their structural relationships
#
# Currently testing this out with the [Gnosis Safe contract](https://github.com/gnosis/safe-contracts/blob/main/contracts/GnosisSafe.sol).

# %% [markdown]
# ## Get contents of contract
# Eventually, this could pull from an external file specifying contracts to parse so that we can iterate through all contracts in one script/notebook.

# %%
url = 'https://raw.githubusercontent.com/gnosis/safe-contracts/main/contracts/GnosisSafe.sol'
fpath = '/tmp/solidity.txt'

# %%
# Get content of Gnosis Safe contract and save to temporary file
content = requests.get(url).text
with open(fpath, 'w') as f:
    f.write(content)

# %% [markdown]
# ## Parse contract
# Use the `solidity_parser` library to parse the contract as an [abstract syntax tree](https://en.wikipedia.org/wiki/Abstract_syntax_tree) (AST). This gets us the full structure of the contract, including functions, their parameters, and which functions call which other functions.
#
# Since this libarry does not preserve comments, add location information to the AST nodes so that later we can go back to the text and extract the relevant function/parameter descriptions.

# %%
# Parse contract as AST
sourceUnit = parser.parse_file(fpath, loc=True) # loc=True -> add location information to ast nodes
pprint.pprint(sourceUnit)
# Out:
# {'children': [{'loc': {'end': {'column': 30, 'line': 2},
#                        'start': {'column': 0, 'line': 2}},
#                'name': 'solidity',
#                'type': 'PragmaDirective',
#                'value': '>=0.7.0<0.9.0'},
#               {'loc': {'end': {'column': 33, 'line': 4},
#                        'start': {'column': 0, 'line': 4}},
#                'path': './base/ModuleManager.sol',
#                'symbolAliases': {},
#                'type': 'ImportDirective',
#                'unitAlias': None},
#               {'loc': {'end': {'column': 32, 'line': 5},
#                        'start': {'column': 0, 'line': 5}},
#                'path': './base/OwnerManager.sol',
#                'symbolAliases': {},
#                'type': 'ImportDirective',
#                'unitAlias': None},
#               {'loc': {'end': {'column': 35, 'line': 6},
#                        'start': {'column': 0, 'line': 6}},
#                'path': './base/FallbackManager.sol',
#                'symbolAliases': {},
#                'type': 'ImportDirective',
#                'unitAlias': None},
#               {'loc': {'end': {'column': 32, 'line': 7},
#                        'start': {'column': 0, 'line': 7}},
#                'path': './base/GuardManager.sol',
#                'symbolAliases': {},
#                'type': 'ImportDirective',
#                'unitAlias': None},
#               {'loc': {'end': {'column': 42, 'line': 8},
#                        'start': {'column': 0, 'line': 8}},
#                'path': './common/EtherPaymentFallback.sol',
#                'symbolAliases': {},
#                'type': 'ImportDirective',
#                'unitAlias': None},
#               {'loc': {'end': {'column': 31, 'line': 9},
#                        'start': {'column': 0, 'line': 9}},
#                'path': './common/Singleton.sol',
#                'symbolAliases': {},
#                'type': 'ImportDirective',
#                'unitAlias': None},
#               {'loc': {'end': {'column': 38, 'line': 10},
#                        'start': {'column': 0, 'line': 10}},
#                'path': './common/SignatureDecoder.sol',
#                'symbolAliases': {},
#                'type': 'ImportDirective',
#                'unitAlias': None},
#               {'loc': {'end': {'column': 42, 'line': 11},
#                        'start': {'column': 0, 'line': 11}},
#                'path': './common/SecuredTokenTransfer.sol',
#                'symbolAliases': {},
#                'type': 'ImportDirective',
#                'unitAlias': None},
#               {'loc': {'end': {'column': 39, 'line': 12},
#                        'start': {'column': 0, 'line': 12}},
#                'path': './common/StorageAccessible.sol',
#                'symbolAliases': {},
#                'type': 'ImportDirective',
#                'unitAlias': None},
#               {'loc': {'end': {'column': 45, 'line': 13},
#                        'start': {'column': 0, 'line': 13}},
#                'path': './interfaces/ISignatureValidator.sol',
#                'symbolAliases': {},
#                'type': 'ImportDirective',
#                'unitAlias': None},
#               {'loc': {'end': {'column': 38, 'line': 14},
#                        'start': {'column': 0, 'line': 14}},
#                'path': './external/GnosisSafeMath.sol',
#                'symbolAliases': {},
#                'type': 'ImportDirective',
#                'unitAlias': None},
#               {'baseContracts': [{'arguments': None,
#                                   'baseName': {'loc': {'end': {'column': 4,
#                                                                'line': 20},
#                                                        'start': {'column': 4,
#                                                                  'line': 20}},
#                                                'namePath': 'EtherPaymentFallback',
#                                                'type': 'UserDefinedTypeName'},
#                                   'loc': {'end': {'column': 4, 'line': 20},
#                                           'start': {'column': 4, 'line': 20}},
#                                   'type': 'InheritanceSpecifier'},
#                                  {'arguments': None,
#                                   'baseName': {'loc': {'end': {'column': 4,
#                                                                'line': 21},
#                                                        'start': {'column': 4,
#                                                                  'line': 21}},
#                                                'namePath': 'Singleton',
#                                                'type': 'UserDefinedTypeName'},
#                                   'loc': {'end': {'column': 4, 'line': 21},
#                                           'start': {'column': 4, 'line': 21}},
#                                   'type': 'InheritanceSpecifier'},
#                                  {'arguments': None,
#                                   'baseName': {'loc': {'end': {'column': 4,
#                                                                'line': 22},
#                                                        'start': {'column': 4,
#                                                                  'line': 22}},
#                                                'namePath': 'ModuleManager',
#                                                'type': 'UserDefinedTypeName'},
#                                   'loc': {'end': {'column': 4, 'line': 22},
#                                           'start': {'column': 4, 'line': 22}},
#                                   'type': 'InheritanceSpecifier'},
#                                  {'arguments': None,
#                                   'baseName': {'loc': {'end': {'column': 4,
#                                                                'line': 23},
#                                                        'start': {'column': 4,
#                                                                  'line': 23}},
#                                                'namePath': 'OwnerManager',
#                                                'type': 'UserDefinedTypeName'},
#                                   'loc': {'end': {'column': 4, 'line': 23},
#                                           'start': {'column': 4, 'line': 23}},
#                                   'type': 'InheritanceSpecifier'},
#                                  {'arguments': None,
#                                   'baseName': {'loc': {'end': {'column': 4,
#                                                                'line': 24},
#                                                        'start': {'column': 4,
#                                                                  'line': 24}},
#                                                'namePath': 'SignatureDecoder',
#                                                'type': 'UserDefinedTypeName'},
#                                   'loc': {'end': {'column': 4, 'line': 24},
#                                           'start': {'column': 4, 'line': 24}},
#                                   'type': 'InheritanceSpecifier'},
#                                  {'arguments': None,
#                                   'baseName': {'loc': {'end': {'column': 4,
#                                                                'line': 25},
#                                                        'start': {'column': 4,
#                                                                  'line': 25}},
#                                                'namePath': 'SecuredTokenTransfer',
#                                                'type': 'UserDefinedTypeName'},
#                                   'loc': {'end': {'column': 4, 'line': 25},
#                                           'start': {'column': 4, 'line': 25}},
#                                   'type': 'InheritanceSpecifier'},
#                                  {'arguments': None,
#                                   'baseName': {'loc': {'end': {'column': 4,
#                                                                'line': 26},
#                                                        'start': {'column': 4,
#                                                                  'line': 26}},
#                                                'namePath': 'ISignatureValidatorConstants',
#                                                'type': 'UserDefinedTypeName'},
#                                   'loc': {'end': {'column': 4, 'line': 26},
#                                           'start': {'column': 4, 'line': 26}},
#                                   'type': 'InheritanceSpecifier'},
#                                  {'arguments': None,
#                                   'baseName': {'loc': {'end': {'column': 4,
#                                                                'line': 27},
#                                                        'start': {'column': 4,
#                                                                  'line': 27}},
#                                                'namePath': 'FallbackManager',
#                                                'type': 'UserDefinedTypeName'},
#                                   'loc': {'end': {'column': 4, 'line': 27},
#                                           'start': {'column': 4, 'line': 27}},
#                                   'type': 'InheritanceSpecifier'},
#                                  {'arguments': None,
#                                   'baseName': {'loc': {'end': {'column': 4,
#                                                                'line': 28},
#                                                        'start': {'column': 4,
#                                                                  'line': 28}},
#                                                'namePath': 'StorageAccessible',
#                                                'type': 'UserDefinedTypeName'},
#                                   'loc': {'end': {'column': 4, 'line': 28},
#                                           'start': {'column': 4, 'line': 28}},
#                                   'type': 'InheritanceSpecifier'},
#                                  {'arguments': None,
#                                   'baseName': {'loc': {'end': {'column': 4,
#                                                                'line': 29},
#                                                        'start': {'column': 4,
#                                                                  'line': 29}},
#                                                'namePath': 'GuardManager',
#                                                'type': 'UserDefinedTypeName'},
#                                   'loc': {'end': {'column': 4, 'line': 29},
#                                           'start': {'column': 4, 'line': 29}},
#                                   'type': 'InheritanceSpecifier'}],
#                'kind': 'contract',
#                'loc': {'end': {'column': 0, 'line': 422},
#                        'start': {'column': 0, 'line': 19}},
#                'name': 'GnosisSafe',
#                'subNodes': [{'libraryName': 'GnosisSafeMath',
#                              'loc': {'end': {'column': 36, 'line': 31},
#                                      'start': {'column': 4, 'line': 31}},
#                              'type': 'UsingForDeclaration',
#                              'typeName': {'loc': {'end': {'column': 29,
#                                                           'line': 31},
#                                                   'start': {'column': 29,
#                                                             'line': 31}},
#                                           'name': 'uint256',
#                                           'type': 'ElementaryTypeName'}},
#                             {'initialValue': {'loc': {'end': {'column': 37,
#                                                               'line': 33},
#                                                       'start': {'column': 37,
#                                                                 'line': 33}},
#                                               'type': 'stringLiteral',
#                                               'value': '1.3.0'},
#                              'loc': {'end': {'column': 44, 'line': 33},
#                                      'start': {'column': 4, 'line': 33}},
#                              'type': 'StateVariableDeclaration',
#                              'variables': [{'expression': {'loc': {'end': {'column': 37,
#                                                                            'line': 33},
#                                                                    'start': {'column': 37,
#                                                                              'line': 33}},
#                                                            'type': 'stringLiteral',
#                                                            'value': '1.3.0'},
#                                             'isDeclaredConst': True,
#                                             'isIndexed': False,
#                                             'isStateVar': True,
#                                             'loc': {'end': {'column': 44,
#                                                             'line': 33},
#                                                     'start': {'column': 4,
#                                                               'line': 33}},
#                                             'name': 'VERSION',
#                                             'type': 'VariableDeclaration',
#                                             'typeName': {'loc': {'end': {'column': 4,
#                                                                          'line': 33},
#                                                                  'start': {'column': 4,
#                                                                            'line': 33}},
#                                                          'name': 'string',
#                                                          'type': 'ElementaryTypeName'},
#                                             'visibility': 'public'}]},
#                             {'initialValue': {'loc': {'end': {'column': 57,
#                                                               'line': 38},
#                                                       'start': {'column': 57,
#                                                                 'line': 38}},
#                                               'number': '0x47e79534a245952e8b16893a336b85a3d9ea9fa8c573f3d803afb92a79469218',
#                                               'subdenomination': None,
#                                               'type': 'NumberLiteral'},
#                              'loc': {'end': {'column': 123, 'line': 38},
#                                      'start': {'column': 4, 'line': 38}},
#                              'type': 'StateVariableDeclaration',
#                              'variables': [{'expression': {'loc': {'end': {'column': 57,
#                                                                            'line': 38},
#                                                                    'start': {'column': 57,
#                                                                              'line': 38}},
#                                                            'number': '0x47e79534a245952e8b16893a336b85a3d9ea9fa8c573f3d803afb92a79469218',
#                                                            'subdenomination': None,
#                                                            'type': 'NumberLiteral'},
#                                             'isDeclaredConst': True,
#                                             'isIndexed': False,
#                                             'isStateVar': True,
#                                             'loc': {'end': {'column': 123,
#                                                             'line': 38},
#                                                     'start': {'column': 4,
#                                                               'line': 38}},
#                                             'name': 'DOMAIN_SEPARATOR_TYPEHASH',
#                                             'type': 'VariableDeclaration',
#                                             'typeName': {'loc': {'end': {'column': 4,
#                                                                          'line': 38},
#                                                                  'start': {'column': 4,
#                                                                            'line': 38}},
#                                                          'name': 'bytes32',
#                                                          'type': 'ElementaryTypeName'},
#                                             'visibility': 'private'}]},
#                             {'initialValue': {'loc': {'end': {'column': 48,
#                                                               'line': 43},
#                                                       'start': {'column': 48,
#                                                                 'line': 43}},
#                                               'number': '0xbb8310d486368db6bd6f849402fdd73ad53d316b5a4b2644ad6efe0f941286d8',
#                                               'subdenomination': None,
#                                               'type': 'NumberLiteral'},
#                              'loc': {'end': {'column': 114, 'line': 43},
#                                      'start': {'column': 4, 'line': 43}},
#                              'type': 'StateVariableDeclaration',
#                              'variables': [{'expression': {'loc': {'end': {'column': 48,
#                                                                            'line': 43},
#                                                                    'start': {'column': 48,
#                                                                              'line': 43}},
#                                                            'number': '0xbb8310d486368db6bd6f849402fdd73ad53d316b5a4b2644ad6efe0f941286d8',
#                                                            'subdenomination': None,
#                                                            'type': 'NumberLiteral'},
#                                             'isDeclaredConst': True,
#                                             'isIndexed': False,
#                                             'isStateVar': True,
#                                             'loc': {'end': {'column': 114,
#                                                             'line': 43},
#                                                     'start': {'column': 4,
#                                                               'line': 43}},
#                                             'name': 'SAFE_TX_TYPEHASH',
#                                             'type': 'VariableDeclaration',
#                                             'typeName': {'loc': {'end': {'column': 4,
#                                                                          'line': 43},
#                                                                  'start': {'column': 4,
#                                                                            'line': 43}},
#                                                          'name': 'bytes32',
#                                                          'type': 'ElementaryTypeName'},
#                                             'visibility': 'private'}]},
#                             {'isAnonymous': False,
#                              'loc': {'end': {'column': 129, 'line': 45},
#                                      'start': {'column': 4, 'line': 45}},
#                              'name': 'SafeSetup',
#                              'parameters': {'loc': {'end': {'column': 128,
#                                                             'line': 45},
#                                                     'start': {'column': 19,
#                                                               'line': 45}},
#                                             'parameters': [{'isIndexed': True,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 128,
#                                                                             'line': 45},
#                                                                     'start': {'column': 19,
#                                                                               'line': 45}},
#                                                             'name': 'initiator',
#                                                             'type': 'VariableDeclaration',
#                                                             'typeName': {'loc': {'end': {'column': 20,
#                                                                                          'line': 45},
#                                                                                  'start': {'column': 20,
#                                                                                            'line': 45}},
#                                                                          'name': 'address',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 128,
#                                                                             'line': 45},
#                                                                     'start': {'column': 19,
#                                                                               'line': 45}},
#                                                             'name': 'owners',
#                                                             'type': 'VariableDeclaration',
#                                                             'typeName': {'baseTypeName': {'loc': {'end': {'column': 47,
#                                                                                                           'line': 45},
#                                                                                                   'start': {'column': 47,
#                                                                                                             'line': 45}},
#                                                                                           'name': 'address',
#                                                                                           'type': 'ElementaryTypeName'},
#                                                                          'length': None,
#                                                                          'loc': {'end': {'column': 55,
#                                                                                          'line': 45},
#                                                                                  'start': {'column': 47,
#                                                                                            'line': 45}},
#                                                                          'type': 'ArrayTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 128,
#                                                                             'line': 45},
#                                                                     'start': {'column': 19,
#                                                                               'line': 45}},
#                                                             'name': 'threshold',
#                                                             'type': 'VariableDeclaration',
#                                                             'typeName': {'loc': {'end': {'column': 65,
#                                                                                          'line': 45},
#                                                                                  'start': {'column': 65,
#                                                                                            'line': 45}},
#                                                                          'name': 'uint256',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 128,
#                                                                             'line': 45},
#                                                                     'start': {'column': 19,
#                                                                               'line': 45}},
#                                                             'name': 'initializer',
#                                                             'type': 'VariableDeclaration',
#                                                             'typeName': {'loc': {'end': {'column': 84,
#                                                                                          'line': 45},
#                                                                                  'start': {'column': 84,
#                                                                                            'line': 45}},
#                                                                          'name': 'address',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 128,
#                                                                             'line': 45},
#                                                                     'start': {'column': 19,
#                                                                               'line': 45}},
#                                                             'name': 'fallbackHandler',
#                                                             'type': 'VariableDeclaration',
#                                                             'typeName': {'loc': {'end': {'column': 105,
#                                                                                          'line': 45},
#                                                                                  'start': {'column': 105,
#                                                                                            'line': 45}},
#                                                                          'name': 'address',
#                                                                          'type': 'ElementaryTypeName'}}],
#                                             'type': 'ParameterList'},
#                              'type': 'EventDefinition'},
#                             {'isAnonymous': False,
#                              'loc': {'end': {'column': 74, 'line': 46},
#                                      'start': {'column': 4, 'line': 46}},
#                              'name': 'ApproveHash',
#                              'parameters': {'loc': {'end': {'column': 73,
#                                                             'line': 46},
#                                                     'start': {'column': 21,
#                                                               'line': 46}},
#                                             'parameters': [{'isIndexed': True,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 73,
#                                                                             'line': 46},
#                                                                     'start': {'column': 21,
#                                                                               'line': 46}},
#                                                             'name': 'approvedHash',
#                                                             'type': 'VariableDeclaration',
#                                                             'typeName': {'loc': {'end': {'column': 22,
#                                                                                          'line': 46},
#                                                                                  'start': {'column': 22,
#                                                                                            'line': 46}},
#                                                                          'name': 'bytes32',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': True,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 73,
#                                                                             'line': 46},
#                                                                     'start': {'column': 21,
#                                                                               'line': 46}},
#                                                             'name': 'owner',
#                                                             'type': 'VariableDeclaration',
#                                                             'typeName': {'loc': {'end': {'column': 52,
#                                                                                          'line': 46},
#                                                                                  'start': {'column': 52,
#                                                                                            'line': 46}},
#                                                                          'name': 'address',
#                                                                          'type': 'ElementaryTypeName'}}],
#                                             'type': 'ParameterList'},
#                              'type': 'EventDefinition'},
#                             {'isAnonymous': False,
#                              'loc': {'end': {'column': 42, 'line': 47},
#                                      'start': {'column': 4, 'line': 47}},
#                              'name': 'SignMsg',
#                              'parameters': {'loc': {'end': {'column': 41,
#                                                             'line': 47},
#                                                     'start': {'column': 17,
#                                                               'line': 47}},
#                                             'parameters': [{'isIndexed': True,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 41,
#                                                                             'line': 47},
#                                                                     'start': {'column': 17,
#                                                                               'line': 47}},
#                                                             'name': 'msgHash',
#                                                             'type': 'VariableDeclaration',
#                                                             'typeName': {'loc': {'end': {'column': 18,
#                                                                                          'line': 47},
#                                                                                  'start': {'column': 18,
#                                                                                            'line': 47}},
#                                                                          'name': 'bytes32',
#                                                                          'type': 'ElementaryTypeName'}}],
#                                             'type': 'ParameterList'},
#                              'type': 'EventDefinition'},
#                             {'isAnonymous': False,
#                              'loc': {'end': {'column': 59, 'line': 48},
#                                      'start': {'column': 4, 'line': 48}},
#                              'name': 'ExecutionFailure',
#                              'parameters': {'loc': {'end': {'column': 58,
#                                                             'line': 48},
#                                                     'start': {'column': 26,
#                                                               'line': 48}},
#                                             'parameters': [{'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 58,
#                                                                             'line': 48},
#                                                                     'start': {'column': 26,
#                                                                               'line': 48}},
#                                                             'name': 'txHash',
#                                                             'type': 'VariableDeclaration',
#                                                             'typeName': {'loc': {'end': {'column': 27,
#                                                                                          'line': 48},
#                                                                                  'start': {'column': 27,
#                                                                                            'line': 48}},
#                                                                          'name': 'bytes32',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 58,
#                                                                             'line': 48},
#                                                                     'start': {'column': 26,
#                                                                               'line': 48}},
#                                                             'name': 'payment',
#                                                             'type': 'VariableDeclaration',
#                                                             'typeName': {'loc': {'end': {'column': 43,
#                                                                                          'line': 48},
#                                                                                  'start': {'column': 43,
#                                                                                            'line': 48}},
#                                                                          'name': 'uint256',
#                                                                          'type': 'ElementaryTypeName'}}],
#                                             'type': 'ParameterList'},
#                              'type': 'EventDefinition'},
#                             {'isAnonymous': False,
#                              'loc': {'end': {'column': 59, 'line': 49},
#                                      'start': {'column': 4, 'line': 49}},
#                              'name': 'ExecutionSuccess',
#                              'parameters': {'loc': {'end': {'column': 58,
#                                                             'line': 49},
#                                                     'start': {'column': 26,
#                                                               'line': 49}},
#                                             'parameters': [{'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 58,
#                                                                             'line': 49},
#                                                                     'start': {'column': 26,
#                                                                               'line': 49}},
#                                                             'name': 'txHash',
#                                                             'type': 'VariableDeclaration',
#                                                             'typeName': {'loc': {'end': {'column': 27,
#                                                                                          'line': 49},
#                                                                                  'start': {'column': 27,
#                                                                                            'line': 49}},
#                                                                          'name': 'bytes32',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 58,
#                                                                             'line': 49},
#                                                                     'start': {'column': 26,
#                                                                               'line': 49}},
#                                                             'name': 'payment',
#                                                             'type': 'VariableDeclaration',
#                                                             'typeName': {'loc': {'end': {'column': 43,
#                                                                                          'line': 49},
#                                                                                  'start': {'column': 43,
#                                                                                            'line': 49}},
#                                                                          'name': 'uint256',
#                                                                          'type': 'ElementaryTypeName'}}],
#                                             'type': 'ParameterList'},
#                              'type': 'EventDefinition'},
#                             {'initialValue': None,
#                              'loc': {'end': {'column': 24, 'line': 51},
#                                      'start': {'column': 4, 'line': 51}},
#                              'type': 'StateVariableDeclaration',
#                              'variables': [{'expression': None,
#                                             'isDeclaredConst': False,
#                                             'isIndexed': False,
#                                             'isStateVar': True,
#                                             'loc': {'end': {'column': 24,
#                                                             'line': 51},
#                                                     'start': {'column': 4,
#                                                               'line': 51}},
#                                             'name': 'nonce',
#                                             'type': 'VariableDeclaration',
#                                             'typeName': {'loc': {'end': {'column': 4,
#                                                                          'line': 51},
#                                                                  'start': {'column': 4,
#                                                                            'line': 51}},
#                                                          'name': 'uint256',
#                                                          'type': 'ElementaryTypeName'},
#                                             'visibility': 'public'}]},
#                             {'initialValue': None,
#                              'loc': {'end': {'column': 46, 'line': 52},
#                                      'start': {'column': 4, 'line': 52}},
#                              'type': 'StateVariableDeclaration',
#                              'variables': [{'expression': None,
#                                             'isDeclaredConst': False,
#                                             'isIndexed': False,
#                                             'isStateVar': True,
#                                             'loc': {'end': {'column': 46,
#                                                             'line': 52},
#                                                     'start': {'column': 4,
#                                                               'line': 52}},
#                                             'name': '_deprecatedDomainSeparator',
#                                             'type': 'VariableDeclaration',
#                                             'typeName': {'loc': {'end': {'column': 4,
#                                                                          'line': 52},
#                                                                  'start': {'column': 4,
#                                                                            'line': 52}},
#                                                          'name': 'bytes32',
#                                                          'type': 'ElementaryTypeName'},
#                                             'visibility': 'private'}]},
#                             {'initialValue': None,
#                              'loc': {'end': {'column': 53, 'line': 54},
#                                      'start': {'column': 4, 'line': 54}},
#                              'type': 'StateVariableDeclaration',
#                              'variables': [{'expression': None,
#                                             'isDeclaredConst': False,
#                                             'isIndexed': False,
#                                             'isStateVar': True,
#                                             'loc': {'end': {'column': 53,
#                                                             'line': 54},
#                                                     'start': {'column': 4,
#                                                               'line': 54}},
#                                             'name': 'signedMessages',
#                                             'type': 'VariableDeclaration',
#                                             'typeName': {'keyType': {'loc': {'end': {'column': 12,
#                                                                                      'line': 54},
#                                                                              'start': {'column': 12,
#                                                                                        'line': 54}},
#                                                                      'name': 'bytes32',
#                                                                      'type': 'ElementaryTypeName'},
#                                                          'loc': {'end': {'column': 30,
#                                                                          'line': 54},
#                                                                  'start': {'column': 4,
#                                                                            'line': 54}},
#                                                          'type': 'Mapping',
#                                                          'valueType': {'loc': {'end': {'column': 23,
#                                                                                        'line': 54},
#                                                                                'start': {'column': 23,
#                                                                                          'line': 54}},
#                                                                        'name': 'uint256',
#                                                                        'type': 'ElementaryTypeName'}},
#                                             'visibility': 'public'}]},
#                             {'initialValue': None,
#                              'loc': {'end': {'column': 73, 'line': 56},
#                                      'start': {'column': 4, 'line': 56}},
#                              'type': 'StateVariableDeclaration',
#                              'variables': [{'expression': None,
#                                             'isDeclaredConst': False,
#                                             'isIndexed': False,
#                                             'isStateVar': True,
#                                             'loc': {'end': {'column': 73,
#                                                             'line': 56},
#                                                     'start': {'column': 4,
#                                                               'line': 56}},
#                                             'name': 'approvedHashes',
#                                             'type': 'VariableDeclaration',
#                                             'typeName': {'keyType': {'loc': {'end': {'column': 12,
#                                                                                      'line': 56},
#                                                                              'start': {'column': 12,
#                                                                                        'line': 56}},
#                                                                      'name': 'address',
#                                                                      'type': 'ElementaryTypeName'},
#                                                          'loc': {'end': {'column': 50,
#                                                                          'line': 56},
#                                                                  'start': {'column': 4,
#                                                                            'line': 56}},
#                                                          'type': 'Mapping',
#                                                          'valueType': {'keyType': {'loc': {'end': {'column': 31,
#                                                                                                    'line': 56},
#                                                                                            'start': {'column': 31,
#                                                                                                      'line': 56}},
#                                                                                    'name': 'bytes32',
#                                                                                    'type': 'ElementaryTypeName'},
#                                                                        'loc': {'end': {'column': 49,
#                                                                                        'line': 56},
#                                                                                'start': {'column': 23,
# ...
#                                                             'loc': {'end': {'column': 16,
#                                                                             'line': 409},
#                                                                     'start': {'column': 8,
#                                                                               'line': 409}},
#                                                             'name': 'to',
#                                                             'storageLocation': None,
#                                                             'type': 'Parameter',
#                                                             'typeName': {'loc': {'end': {'column': 8,
#                                                                                          'line': 409},
#                                                                                  'start': {'column': 8,
#                                                                                            'line': 409}},
#                                                                          'name': 'address',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 16,
#                                                                             'line': 410},
#                                                                     'start': {'column': 8,
#                                                                               'line': 410}},
#                                                             'name': 'value',
#                                                             'storageLocation': None,
#                                                             'type': 'Parameter',
#                                                             'typeName': {'loc': {'end': {'column': 8,
#                                                                                          'line': 410},
#                                                                                  'start': {'column': 8,
#                                                                                            'line': 410}},
#                                                                          'name': 'uint256',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 23,
#                                                                             'line': 411},
#                                                                     'start': {'column': 8,
#                                                                               'line': 411}},
#                                                             'name': 'data',
#                                                             'storageLocation': 'calldata',
#                                                             'type': 'Parameter',
#                                                             'typeName': {'loc': {'end': {'column': 8,
#                                                                                          'line': 411},
#                                                                                  'start': {'column': 8,
#                                                                                            'line': 411}},
#                                                                          'name': 'bytes',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 23,
#                                                                             'line': 412},
#                                                                     'start': {'column': 8,
#                                                                               'line': 412}},
#                                                             'name': 'operation',
#                                                             'storageLocation': None,
#                                                             'type': 'Parameter',
#                                                             'typeName': {'loc': {'end': {'column': 13,
#                                                                                          'line': 412},
#                                                                                  'start': {'column': 8,
#                                                                                            'line': 412}},
#                                                                          'namePath': 'Enum.Operation',
#                                                                          'type': 'UserDefinedTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 16,
#                                                                             'line': 413},
#                                                                     'start': {'column': 8,
#                                                                               'line': 413}},
#                                                             'name': 'safeTxGas',
#                                                             'storageLocation': None,
#                                                             'type': 'Parameter',
#                                                             'typeName': {'loc': {'end': {'column': 8,
#                                                                                          'line': 413},
#                                                                                  'start': {'column': 8,
#                                                                                            'line': 413}},
#                                                                          'name': 'uint256',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 16,
#                                                                             'line': 414},
#                                                                     'start': {'column': 8,
#                                                                               'line': 414}},
#                                                             'name': 'baseGas',
#                                                             'storageLocation': None,
#                                                             'type': 'Parameter',
#                                                             'typeName': {'loc': {'end': {'column': 8,
#                                                                                          'line': 414},
#                                                                                  'start': {'column': 8,
#                                                                                            'line': 414}},
#                                                                          'name': 'uint256',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 16,
#                                                                             'line': 415},
#                                                                     'start': {'column': 8,
#                                                                               'line': 415}},
#                                                             'name': 'gasPrice',
#                                                             'storageLocation': None,
#                                                             'type': 'Parameter',
#                                                             'typeName': {'loc': {'end': {'column': 8,
#                                                                                          'line': 415},
#                                                                                  'start': {'column': 8,
#                                                                                            'line': 415}},
#                                                                          'name': 'uint256',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 16,
#                                                                             'line': 416},
#                                                                     'start': {'column': 8,
#                                                                               'line': 416}},
#                                                             'name': 'gasToken',
#                                                             'storageLocation': None,
#                                                             'type': 'Parameter',
#                                                             'typeName': {'loc': {'end': {'column': 8,
#                                                                                          'line': 416},
#                                                                                  'start': {'column': 8,
#                                                                                            'line': 416}},
#                                                                          'name': 'address',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 16,
#                                                                             'line': 417},
#                                                                     'start': {'column': 8,
#                                                                               'line': 417}},
#                                                             'name': 'refundReceiver',
#                                                             'storageLocation': None,
#                                                             'type': 'Parameter',
#                                                             'typeName': {'loc': {'end': {'column': 8,
#                                                                                          'line': 417},
#                                                                                  'start': {'column': 8,
#                                                                                            'line': 417}},
#                                                                          'name': 'address',
#                                                                          'type': 'ElementaryTypeName'}},
#                                                            {'isIndexed': False,
#                                                             'isStateVar': False,
#                                                             'loc': {'end': {'column': 16,
#                                                                             'line': 418},
#                                                                     'start': {'column': 8,
#                                                                               'line': 418}},
#                                                             'name': '_nonce',
#                                                             'storageLocation': None,
#                                                             'type': 'Parameter',
#                                                             'typeName': {'loc': {'end': {'column': 8,
#                                                                                          'line': 418},
#                                                                                  'start': {'column': 8,
#                                                                                            'line': 418}},
#                                                                          'name': 'uint256',
#                                                                          'type': 'ElementaryTypeName'}}],
#                                             'type': 'ParameterList'},
#                              'returnParameters': {'loc': {'end': {'column': 34,
#                                                                   'line': 419},
#                                                           'start': {'column': 26,
#                                                                     'line': 419}},
#                                                   'parameters': [{'isIndexed': False,
#                                                                   'isStateVar': False,
#                                                                   'loc': {'end': {'column': 27,
#                                                                                   'line': 419},
#                                                                           'start': {'column': 27,
#                                                                                     'line': 419}},
#                                                                   'name': None,
#                                                                   'storageLocation': None,
#                                                                   'type': 'Parameter',
#                                                                   'typeName': {'loc': {'end': {'column': 27,
#                                                                                                'line': 419},
#                                                                                        'start': {'column': 27,
#                                                                                                  'line': 419}},
#                                                                                'name': 'bytes32',
#                                                                                'type': 'ElementaryTypeName'}}],
#                                                   'type': 'ParameterList'},
#                              'stateMutability': 'view',
#                              'type': 'FunctionDefinition',
#                              'visibility': 'public'}],
#                'type': 'ContractDefinition'}],
#  'loc': {'end': {'column': 0, 'line': 422}, 'start': {'column': 0, 'line': 2}},
#  'type': 'SourceUnit'}

# %%
sourceUnitObject = parser.objectify(sourceUnit)
sourceUnitObject.contracts["GnosisSafe"].functions.keys()
# Out:
# dict_keys(['constructor', 'setup', 'execTransaction', 'handlePayment', 'checkSignatures', 'checkNSignatures', 'requiredTxGas', 'approveHash', 'getChainId', 'domainSeparator', 'encodeTransactionData', 'getTransactionHash'])
